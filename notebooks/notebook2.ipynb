# %%
print("this is my second notebook")
# Out:
# this is my second notebook

# %%
from datetime import datetime
from zoneinfo import ZoneInfo

# Fetch the current time in Indian Standard Time (IST)
ist_time = datetime.now(ZoneInfo("Asia/Kolkata"))

print("Current IST Time:", ist_time)
# To format it nicely:
print("Formatted:", ist_time.strftime("%Y-%m-%d %H:%M:%S"))
# Out:
# Current IST Time: 2026-08-21 13:36:14.638816+05:30
# Formatted: 2026-08-21 13:36:14
